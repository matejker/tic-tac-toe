# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 1.01, 0.01)

plt.figure(figsize=(10, 10))
plt.axis('off')

plt.plot([1, 2, 2, 1, 1], [1, 1, 2, 2, 1], 'k:', alpha=.2)

plt.plot([0.95, 2.05], [0.95, 2.05], 'g--', alpha=.7)
plt.plot([2.05, 0.95], [0.95, 2.05], 'g--', alpha=.7)
plt.plot([1.5, 1.5], [0.95, 2.05], 'g--', alpha=.7)
plt.plot([0.95, 2.05], [1.5, 1.5], 'g--', alpha=.7)

plt.plot(.8  * np.cos(x[:76] * 2 * np.pi) + 1.5, .8 * np.sin(x[:76] * 2 * np.pi) + 1.5, 'c')
plt.plot(.85  * np.cos(x[:51] * 2 * np.pi) + 1.5, .85 * np.sin(x[:51] * 2 * np.pi) + 1.5, 'c')
plt.plot(.9  * np.cos(x[:26] * 2 * np.pi) + 1.5, .9 * np.sin(x[:26] * 2 * np.pi) + 1.5, 'c')

plt.scatter(.8 * np.cos(x[75] * 2 * np.pi) + 1.5, .8 * np.sin(x[75] * 2 * np.pi) + 1.5, marker='>', color="c")
plt.scatter(.85 * np.cos(x[50] * 2 * np.pi) + 1.5, .85 * np.sin(x[50] * 2 * np.pi) + 1.5, marker='v', color="c")
plt.scatter(.9 * np.cos(x[25] * 2 * np.pi) + 1.5, .9 * np.sin(x[25] * 2 * np.pi) + 1.5, marker='<', color="c")

plt.text(1.5, 2.10, r"$t_y$", fontsize=20)
plt.text(2.10, 1.5, r"$t_x$", fontsize=20)
plt.text(2.12, 0.87, r"$t_{AC}$", fontsize=20)
plt.text(1, 0.87, r"$t_{BD}$", fontsize=20)

plt.text(.9 * np.cos(x[70] * 2 * np.pi) + 1.5, .9 * np.sin(x[70] * 2 * np.pi) + 1.5, r"$r^3$", fontsize=20)
plt.text(.95 * np.cos(x[45] * 2 * np.pi) + 1.5, .95 * np.sin(x[45] * 2 * np.pi) + 1.5, r"$r^2$", fontsize=20)
plt.text(.95 * np.cos(x[20] * 2 * np.pi) + 1.5, .95 * np.sin(x[20] * 2 * np.pi) + 1.5, r"$r$", fontsize=20)

plt.plot([1.33, 1.33], [1, 2], 'k-', alpha=.8)
plt.plot([1.67, 1.67], [1, 2], 'k-', alpha=.8)
plt.plot([1, 2], [1.33, 1.33], 'k-', alpha=.8)
plt.plot([1, 2], [1.67, 1.67], 'k-', alpha=.8)


plt.text(0.93, 1.03, "D", fontsize=20)
plt.text(2.03, 1.03, "C", fontsize=20)
plt.text(0.93, 1.9, "A", fontsize=20)
plt.text(2.03, 1.9, "B", fontsize=20)

plt.text(1.445, 1.438, "0", fontsize=50, alpha=.8)
plt.text(1.095, 1.425, "8", fontsize=50, alpha=.8)
plt.text(1.095, 1.765, "1", fontsize=50, alpha=.8)
plt.text(1.445, 1.765, "2", fontsize=50, alpha=.8)
plt.text(1.765, 1.765, "3", fontsize=50, alpha=.8)
plt.text(1.765, 1.425, "4", fontsize=50, alpha=.8)
plt.text(1.765, 1.095, "5", fontsize=50, alpha=.8)
plt.text(1.445, 1.095, "6", fontsize=50, alpha=.8)
plt.text(1.095, 1.095, "7", fontsize=50, alpha=.8)
plt.show()

# %%
plt.figure(figsize=(8, 3))
plt.axis('off')


plt.plot([1.33, 1.33], [1, 2], 'k-', alpha=.8)
plt.plot([1.67, 1.67], [1, 2], 'k-', alpha=.8)
plt.plot([1, 2], [1.33, 1.33], 'k-', alpha=.8)
plt.plot([1, 2], [1.67, 1.67], 'k-', alpha=.8)

plt.text(1.42, 1.425, "X", fontsize=30, alpha=.8)
plt.text(1.42, 1.765, "O", fontsize=30, alpha=.8)

plt.plot([3.33, 3.33], [1, 2], 'k-', alpha=.8)
plt.plot([3.67, 3.67], [1, 2], 'k-', alpha=.8)
plt.plot([3, 4], [1.33, 1.33], 'k-', alpha=.8)
plt.plot([3, 4], [1.67, 1.67], 'k-', alpha=.8)

plt.text(3.42, 1.425, "X", fontsize=30, alpha=.8)
plt.text(3.75, 1.425, "O", fontsize=30, alpha=.8)

plt.show()

# %%
plt.figure(figsize=(3, 3))
plt.axis('off')


plt.plot([1.33, 1.33], [1, 2], 'k-', alpha=.8)
plt.plot([1.67, 1.67], [1, 2], 'k-', alpha=.8)
plt.plot([1, 2], [1.33, 1.33], 'k-', alpha=.8)
plt.plot([1, 2], [1.67, 1.67], 'k-', alpha=.8)

plt.text(1.42, 1.425, "X", fontsize=30, alpha=.8)
plt.text(1.765, 1.765, "O", fontsize=30, alpha=.8)
plt.text(1.42, 1.765, "X", fontsize=30, alpha=.8)

plt.show()

# %%
plt.figure(figsize=(16, 12))
plt.axis('off')


plt.plot([3.33, 3.33], [3, 4], 'k-', alpha=.8)
plt.plot([3.67, 3.67], [3, 4], 'k-', alpha=.8)
plt.plot([3, 4], [3.33, 3.33], 'k-', alpha=.8)
plt.plot([3, 4], [3.67, 3.67], 'k-', alpha=.8)

plt.text(3.07, 3.425, "X", fontsize=30, alpha=.8)
plt.text(3.07, 3.765, "X", fontsize=30, alpha=.8)
plt.text(3.07, 3.07, "O", fontsize=30, alpha=.8)

plt.text(3.765, 3.765, "O", fontsize=30, alpha=.8)
plt.text(3.765, 3.07, "X", fontsize=30, alpha=.8)

plt.text(3.42, 3.07, "O", fontsize=30, alpha=.8)

#--------------------------

plt.plot([1.33, 1.33], [1, 2], 'k-', alpha=.8)
plt.plot([1.67, 1.67], [1, 2], 'k-', alpha=.8)
plt.plot([1, 2], [1.33, 1.33], 'k-', alpha=.8)
plt.plot([1, 2], [1.67, 1.67], 'k-', alpha=.8)

plt.text(1.07, 1.425, "X", fontsize=30, alpha=.8)
plt.text(1.07, 1.765, "X", fontsize=30, alpha=.8)
plt.text(1.07, 1.07, "O", fontsize=30, alpha=.8)

plt.text(1.765, 1.07, "X", fontsize=30, alpha=.8)
plt.text(1.765, 1.765, "O", fontsize=30, alpha=.8)

plt.text(1.42, 1.07, "O", fontsize=30, alpha=.8)
plt.text(1.42, 1.765, "X", fontsize=30, alpha=.8)


plt.plot([3.33, 3.33], [1, 2], 'k-', alpha=.8)
plt.plot([3.67, 3.67], [1, 2], 'k-', alpha=.8)
plt.plot([3, 4], [1.33, 1.33], 'k-', alpha=.8)
plt.plot([3, 4], [1.67, 1.67], 'k-', alpha=.8)

plt.text(3.07, 1.425, "X", fontsize=30, alpha=.8)
plt.text(3.07, 1.765, "X", fontsize=30, alpha=.8)
plt.text(3.07, 1.07, "O", fontsize=30, alpha=.8)

plt.text(3.765, 1.765, "O", fontsize=30, alpha=.8)
plt.text(3.765, 1.07, "X", fontsize=30, alpha=.8)


plt.text(3.42, 1.07, "O", fontsize=30, alpha=.8)
plt.text(3.42, 1.425, "X", fontsize=30, alpha=.8)


plt.plot([5.33, 5.33], [1, 2], 'k-', alpha=.8)
plt.plot([5.67, 5.67], [1, 2], 'k-', alpha=.8)
plt.plot([5, 6], [1.33, 1.33], 'k-', alpha=.8)
plt.plot([5, 6], [1.67, 1.67], 'k-', alpha=.8)

plt.text(5.07, 1.425, "X", fontsize=30, alpha=.8)
plt.text(5.07, 1.765, "X", fontsize=30, alpha=.8)
plt.text(5.07, 1.07, "O", fontsize=30, alpha=.8)

plt.text(5.765, 1.07, "X", fontsize=30, alpha=.8)
plt.text(5.765, 1.765, "O", fontsize=30, alpha=.8)
plt.text(5.765, 1.425, "X", fontsize=30, alpha=.8)

plt.text(5.42, 1.07, "O", fontsize=30, alpha=.8)


plt.plot([3.5, 1.5], [2.9, 2.1], "c")
plt.plot([3.5, 3.5], [2.9, 2.1], "c")
plt.plot([3.5, 5.5], [2.9, 2.1], "c")

plt.scatter(1.5, 2.1, marker='o', color="c")
plt.scatter(3.5, 2.1, marker='o', color="c")
plt.scatter(5.5, 2.1, marker='o', color="c")

#--------------------------

plt.plot([0.33, 0.33], [-1, 0], 'k-', alpha=.8)
plt.plot([0.67, 0.67], [-1, 0], 'k-', alpha=.8)
plt.plot([0, 1], [-0.67, -0.67], 'k-', alpha=.8)
plt.plot([0, 1], [-0.33, -0.33], 'k-', alpha=.8)

plt.text(0.07, -0.623, "X", fontsize=30, alpha=.8)
plt.text(0.07, -0.225, "X", fontsize=30, alpha=.8)
plt.text(0.07, -0.93, "O", fontsize=30, alpha=.8)

plt.text(0.765, -0.93, "X", fontsize=30, alpha=.8)
plt.text(0.765, -0.225, "O", fontsize=30, alpha=.8)

plt.text(0.42, -0.93, "O", fontsize=30, alpha=.8)
plt.text(0.42, -0.623, "O", fontsize=30, alpha=.8)
plt.text(0.42, -0.225, "X", fontsize=30, alpha=.8)


plt.plot([2.33, 2.33], [-1, 0], 'k-', alpha=.8)
plt.plot([2.67, 2.67], [-1, 0], 'k-', alpha=.8)
plt.plot([2, 3], [-0.67, -0.67], 'k-', alpha=.8)
plt.plot([2, 3], [-0.33, -0.33], 'k-', alpha=.8)

plt.text(2.07, -0.623, "X", fontsize=30, alpha=.8)
plt.text(2.07, -0.225, "X", fontsize=30, alpha=.8)
plt.text(2.07, -0.93, "O", fontsize=30, alpha=.8)

plt.text(2.765, -0.93, "X", fontsize=30, alpha=.8)
plt.text(2.765, -0.623, "O", fontsize=30, alpha=.8)
plt.text(2.765, -0.225, "O", fontsize=30, alpha=.8)

plt.text(2.42, -0.93, "O", fontsize=30, alpha=.8)
plt.text(2.42, -0.623, "X", fontsize=30, alpha=.2)
plt.text(2.42, -0.225, "X", fontsize=30, alpha=.8)


plt.plot([6.33, 6.33], [-1, 0], 'k-', alpha=.8)
plt.plot([6.67, 6.67], [-1, 0], 'k-', alpha=.8)
plt.plot([6, 7], [-0.67, -0.67], 'k-', alpha=.8)
plt.plot([6, 7], [-0.33, -0.33], 'k-', alpha=.8)

plt.text(6.07, -0.623, "X", fontsize=30, alpha=.8)
plt.text(6.07, -0.225, "X", fontsize=30, alpha=.8)
plt.text(6.07, -0.93, "O", fontsize=30, alpha=.8)

plt.text(6.765, -0.93, "X", fontsize=30, alpha=.8)
plt.text(6.765, -0.225, "O", fontsize=30, alpha=.8)
plt.text(6.765, -0.623, "X", fontsize=30, alpha=.8)

plt.text(6.42, -0.93, "O", fontsize=30, alpha=.8)
plt.text(6.42, -0.623, "X", fontsize=30, alpha=.2)
plt.text(6.42, -0.225, "O", fontsize=30, alpha=.8)


plt.plot([4.33, 4.33], [-1, 0], 'k-', alpha=.8)
plt.plot([4.67, 4.67], [-1, 0], 'k-', alpha=.8)
plt.plot([4, 5], [-0.67, -0.67], 'k-', alpha=.8)
plt.plot([4, 5], [-0.33, -0.33], 'k-', alpha=.8)

plt.text(4.07, -0.623, "X", fontsize=30, alpha=.8)
plt.text(4.07, -0.225, "X", fontsize=30, alpha=.8)
plt.text(4.07, -0.93, "O", fontsize=30, alpha=.8)

plt.text(4.765, -0.93, "X", fontsize=30, alpha=.8)
plt.text(4.765, -0.225, "O", fontsize=30, alpha=.8)
plt.text(4.765, -0.623, "X", fontsize=30, alpha=.8)

plt.text(4.42, -0.93, "O", fontsize=30, alpha=.8)
plt.text(4.42, -0.623, "O", fontsize=30, alpha=.8)

plt.plot([1.5, 0.5], [0.9, 0.1], "c")
plt.plot([1.5, 2.5], [0.9, 0.1], "c")
plt.plot([5.5, 4.5], [0.9, 0.1], "c")
plt.plot([5.5, 6.5], [0.9, 0.1], "c")

plt.scatter(0.5, 0.1, marker='o', color="c")
plt.scatter(2.5, 0.1, marker='o', color="c")
plt.scatter(4.5, 0.1, marker='o', color="c")
plt.scatter(6.5, 0.1, marker='o', color="c")

plt.text(3.2, 0.8, "won +9", fontsize=20, alpha=.8, color="r")
plt.text(0.23, -1.2, "lost -8", fontsize=20, alpha=.8, color="r")
plt.text(2.2, -1.2, "won +7", fontsize=20, alpha=.8, color="r")
plt.text(4.23, -1.2, "lost -8", fontsize=20, alpha=.8, color="r")
plt.text(6.2, -1.2, "won +7", fontsize=20, alpha=.8, color="r")

plt.show()
